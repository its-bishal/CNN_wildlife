# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
# %matplotlib inline

import tensorflow as tf
from skimage import io
import keras
import os
import glob
import random
import pandas as pd
import shutil
from PIL import Image,ImageDraw

from sklearn.model_selection import train_test_split

from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPool2D
from tensorflow.keras.applications import VGG16

# %%
os.chdir('../')
path = 'B:/data/wildlife'

# %%
new_path ="B:/data/wildlife_loc"

def filterImages():
    for dir in os.listdir(path):
        for file in os.listdir(path+'/'+dir):
            if file.endswith('txt'):
                lines = np.loadtxt(path+'/'+dir+'/'+file)
                if lines.size == 5:
                    img = file.split('.')[0]+'.jpg'
                    shutil.copy(path+'/'+dir+'/'+img,f"{new_path}/{dir}")
                    shutil.copy(path+'/'+dir+'/'+file,f"{new_path}/{dir}")
                else:
                    continue
#filterImages()

# %%
#Check to see if bounding boxes are actually correct
#Manually Apply Bounding Boxes with the help of labels.txt 
data = np.loadtxt(new_path+'/buffalo/002.txt')
im = Image.open(new_path+'/buffalo/002.jpg')
w = im.size[0]
h = im.size[1]
x = data[1]*w
y = data[2]*h
width = data[3]*w
height = data[4]*h
draw = ImageDraw.Draw(im)
draw.rectangle((x-width/2,y-height/2,x+width/2,y+height/2),width=1)
im.show()
im.close()

# %%
x_loc = np.zeros((843, 50176, 3), dtype=float)
y_loc = np.zeros(843, dtype=int)
bbox = np.zeros((843,4), dtype=float)
i=0
for dir in os.listdir(new_path):
    for file in os.listdir(new_path+'/'+dir):
        if file.endswith('jpg'):
            org_img = tf.keras.preprocessing.image.load_img(new_path+'/'+dir+'/'+file).resize((224,224))
            org_img_to_array = tf.keras.preprocessing.image.img_to_array(org_img)
            reshaped_img = org_img_to_array.reshape(-1,3)/255.0
            x_loc[i,:,:] = reshaped_img
        else:
            line = np.loadtxt(new_path+'/'+dir+'/'+file)
            bbox[i,:] = line[1:]
            y_loc[i] = line[0]
            i = i+1
print('writing to the file')

with open('x_loc.npy','wb') as f:
    np.save(f,x_loc)
with open('y_loc.npy', 'wb') as f:
    np.save(f, y_loc)
with open('bbox.npy', 'wb') as f:
    np.save(f, bbox)
# Out:
# writing to the file

# %%
with open('x_loc.npy','rb') as f:
    x = np.load('x_loc.npy')
with open('y_loc.npy', 'rb') as f:
    y = np.load('y_loc.npy')
with open('bbox.npy', 'rb') as f:
    z = np.load('bbox.npy')

# %%
first = tf.keras.preprocessing.image.array_to_img(x[842].reshape(224,224,3))
plt.imshow(first)

# %%
X_train, X_, y_train, y_ , z_train, z_ = train_test_split(x, y, z, random_state=False, test_size=0.2, shuffle=True)
X_test, X_val, y_test, y_val, z_test, z_val = train_test_split(X_, y_, z_, random_state=False, test_size=0.5, shuffle=True)

# %%
vgg = VGG16(weights="imagenet", include_top=False, input_tensor=tf.keras.Input(shape=(224, 224, 3)))
vgg.trainable = False
flatten = vgg.output
flatten = Flatten()(flatten)

softmaxHead = Dense(512, activation="relu")(flatten)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(512, activation="relu")(softmaxHead)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(4, activation="softmax", name="class_label")(softmaxHead)

bboxHead = Dense(128, activation="relu")(flatten)
bboxHead = Dense(64, activation="relu")(bboxHead)
bboxHead = Dense(32, activation="relu")(bboxHead)
bboxHead = Dense(4, activation="sigmoid", name="bounding_box")(bboxHead)

model = tf.keras.Model(inputs=vgg.input, outputs=(softmaxHead,bboxHead))

# %%
losses = {
    "class_label": "sparse_categorical_crossentropy",
    "bounding_box": "mean_squared_error",
}

lossWeights = {
    "class_label": 1.0,
    "bounding_box": 1.0
}

# %%
model.compile(loss=losses, optimizer='adam', loss_weights=lossWeights)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 224, 224, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 112, 112, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 112, 112, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 112, 112, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 56, 56, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 56, 56, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 28, 28, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 512)  0           ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 14, 14, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 7, 7, 512)    0           ['block5_conv3[0][0]']
#
#  flatten (Flatten)              (None, 25088)        0           ['block5_pool[0][0]']
#
#  dense (Dense)                  (None, 512)          12845568    ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 128)          3211392     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 512)          262656      ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 64)           8256        ['dense_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_1[0][0]']
#
#  dense_4 (Dense)                (None, 32)           2080        ['dense_3[0][0]']
#
#  class_label (Dense)            (None, 4)            2052        ['dropout_1[0][0]']
#
#  bounding_box (Dense)           (None, 4)            132         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 31,046,824
# Trainable params: 16,332,136
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________
# None

# %%
# construct a dictionary for our target training outputs
trainTargets = {
    "class_label": y_train,
    "bounding_box": z_train
}
# construct a second dictionary, this one for our target testing
# outputs
valTargets = {
    "class_label": y_val,
    "bounding_box": z_val
}

# %%
# train the network for bounding box regression
print("[INFO] training bounding box regressor...")
history = model.fit(X_train.reshape(-1,224,224,3),trainTargets, validation_data=(X_val.reshape(-1,224,224,3),valTargets), batch_size=25, epochs=10, verbose=1)
# Out:
# [INFO] training bounding box regressor...
# Epoch 1/10
# 27/27 [==============================] - 86s 2s/step - loss: 3.7447 - class_label_loss: 3.6646 - bounding_box_loss: 0.0801 - val_loss: 0.8244 - val_class_label_loss: 0.8093 - val_bounding_box_loss: 0.0151
# Epoch 2/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.9781 - class_label_loss: 0.9691 - bounding_box_loss: 0.0089 - val_loss: 0.5335 - val_class_label_loss: 0.5266 - val_bounding_box_loss: 0.0069
# Epoch 3/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.6658 - class_label_loss: 0.6608 - bounding_box_loss: 0.0050 - val_loss: 0.4272 - val_class_label_loss: 0.4199 - val_bounding_box_loss: 0.0073
# Epoch 4/10
# 27/27 [==============================] - 29s 1s/step - loss: 0.5095 - class_label_loss: 0.5059 - bounding_box_loss: 0.0036 - val_loss: 0.2714 - val_class_label_loss: 0.2652 - val_bounding_box_loss: 0.0063
# Epoch 5/10
# 27/27 [==============================] - 29s 1s/step - loss: 0.3903 - class_label_loss: 0.3881 - bounding_box_loss: 0.0022 - val_loss: 0.3148 - val_class_label_loss: 0.3077 - val_bounding_box_loss: 0.0071
# Epoch 6/10
# 27/27 [==============================] - 29s 1s/step - loss: 0.2936 - class_label_loss: 0.2921 - bounding_box_loss: 0.0015 - val_loss: 0.4113 - val_class_label_loss: 0.4054 - val_bounding_box_loss: 0.0059
# Epoch 7/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.2963 - class_label_loss: 0.2952 - bounding_box_loss: 0.0011 - val_loss: 0.3348 - val_class_label_loss: 0.3292 - val_bounding_box_loss: 0.0056
# Epoch 8/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.2213 - class_label_loss: 0.2204 - bounding_box_loss: 8.4778e-04 - val_loss: 0.2472 - val_class_label_loss: 0.2415 - val_bounding_box_loss: 0.0057
# Epoch 9/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.2233 - class_label_loss: 0.2223 - bounding_box_loss: 9.6774e-04 - val_loss: 0.4098 - val_class_label_loss: 0.4045 - val_bounding_box_loss: 0.0054
# Epoch 10/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.1918 - class_label_loss: 0.1906 - bounding_box_loss: 0.0012 - val_loss: 0.2901 - val_class_label_loss: 0.2841 - val_bounding_box_loss: 0.0060

# %%
model.save('models/wildlife_loc.h5')

# %%
from tensorflow.keras.models import load_model
model = load_model('models/wildlife_loc.h5')

# %%
X_test.shape
X_val.shape
# Out:
# (85, 50176, 3)

# %%
fig,axes = plt.subplots(4,4,figsize=(12,12))
fig.tight_layout(pad=0.1)

for i,ax in enumerate(axes.flat):
    randomindex = np.random.randint(84)
    prediction = model.predict(X_test[randomindex].reshape(-1,224,224,3))
    X_random = X_test[randomindex].reshape(224,224,3)
    (x,y,width,height) = prediction[1][0]
    ax.imshow(X_random,cmap="gray")
    ax.add_patch(Rectangle(((x-width/2)*224,(y-height/2)*224), width*224, height*224, edgecolor='red',facecolor='none',lw=1))
    ax.text((x-width/2)*224,(y-height/2)*224,f"{y_test[randomindex]},{np.argmax(prediction[0][0])}",c='blue',fontsize=16)
    ax.set_axis_off()
# Out:
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 134ms/step
